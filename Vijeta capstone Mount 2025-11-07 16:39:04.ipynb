# %%
dbutils.fs.mount(
   source="wasbs://capstone2@vijetaadlscapstone.blob.core.windows.net",
   mount_point="/mnt/vijetaadlscapstone2",
   extra_configs={
       "fs.azure.account.key.vijetaadlscapstone.blob.core.windows.net": dbutils.secrets.get(
           scope="vijetaadlscapstonescope2", key="vijetasecretcapstone"
       )
   }
)
